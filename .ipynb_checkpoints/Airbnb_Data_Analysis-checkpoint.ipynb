# %% [markdown]
# # Import Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Load the dataset

# %%
airbnb= pd.read_csv('/Users/nikita.maloo/Desktop/P/Airbnb Data Analysis/NYC_Airbnb.csv')

# %%
#examining the first 5 rows
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#examining the last 5 rows
airbnb.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %% [markdown]
# Looking at the head and tail of the dataset we can see some missing values(NaN)

# %% [markdown]
# # High Level Statistics

# %% [markdown]
# ### Shape

# %%
airbnb.shape
# Out:
# (48895, 16)

# %%
#Print all the column names
airbnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ### Unique Counts

# %% [markdown]
# Datset has 48895 rows and 16 columns

# %%
#Number fo unique values in each column
airbnb.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# ### Data Types

# %%
airbnb.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
#More info
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
# id                                48895 non-null int64
# name                              48879 non-null object
# host_id                           48895 non-null int64
# host_name                         48874 non-null object
# neighbourhood_group               48895 non-null object
# neighbourhood                     48895 non-null object
# latitude                          48895 non-null float64
# longitude                         48895 non-null float64
# room_type                         48895 non-null object
# price                             48895 non-null int64
# minimum_nights                    48895 non-null int64
# number_of_reviews                 48895 non-null int64
# last_review                       38843 non-null object
# reviews_per_month                 38843 non-null float64
# calculated_host_listings_count    48895 non-null int64
# ...

# %% [markdown]
# ### Describe Continuous Valriables

# %%
#Examining Continous Variables
airbnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Missing Values

# %%
#Lets see which columns have null values
#use 'sum' function to count the number of missing values in each column
airbnb.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#Arraging the columns by the number of missing values
Missing_Count = airbnb.isnull().sum()
Percentage_Of_Missing_Count = airbnb.isnull().sum() / airbnb.count()
Missing_Data = pd.concat([Missing_Count,Percentage_Of_Missing_Count],axis = 1 , keys=['Missing Count','Percentage Of Missing Data']).sort_values('Missing Count', ascending=False)
Missing_Data
# Out:
#                                 Missing Count  Percentage Of Missing Data
# last_review                             10052                    0.258785
# reviews_per_month                       10052                    0.258785
# host_name                                  21                    0.000430
# name                                       16                    0.000327
# id                                          0                    0.000000
# host_id                                     0                    0.000000
# neighbourhood_group                         0                    0.000000
# neighbourhood                               0                    0.000000
# latitude                                    0                    0.000000
# longitude                                   0                    0.000000
# room_type                                   0                    0.000000
# price                                       0                    0.000000
# ...

# %% [markdown]
# ### Duplicate Rows

# %%
#Checking for duplicate rows
airbnb.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48890    False
# 48891    False
# 48892    False
# 48893    False
# 48894    False
# Length: 48895, dtype: bool

# %%
airbnb.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate rows

# %%
#drop the unwated columns
#airbnb.drop(['id','name','host_name', 'last_review'], axis=1, inplace=True)

# %%
#Replacing missing values with 0 in reviews_per_month
airbnb.fillna({'reviews_per_month':0}, inplace=True)

# %%
#examining changes
#airbnb.isnull().sum()

# %%
#Now there are no missing values in the dataset

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ### Variables can be one of two types: categorical or numerical.
#
# ##### Categorical Data
# ##### Categorical data classify items into groups. This type of data can be further broken down into nominal, ordinal, and binary values.
# - Ordinal values have a set order.
# - Nominal values have no set order.
# - Binary data has only two values. This could be represented as True/False or 1/0.
#
#
# ##### Numerical Data
# ##### Numerical data are values that we can perform mathematical operations on. They are further broken down into continuous and discrete data types.
# - Discreet variables have to be an integer.
# - Continuous can be any value.

# %% [markdown]
# ### 1.host_id

# %% [markdown]
# From Unique Counts above we can see that in this dataset there are 37457 unique hosts renting out a total number of 48895 properties

# %%
Top_10_Hosts_With_Most_Properties =airbnb.host_id.value_counts().head(10)
Top_10_Hosts_With_Most_Properties
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 12243051      96
# 16098958      96
# 61391963      91
# 22541573      87
# 200380610     65
# 7503643       52
# Name: host_id, dtype: int64

# %% [markdown]
# ### 2.neighbourhood_group

# %%
#Names of unique neighbourhood_groups
airbnb['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
sns.countplot(airbnb['neighbourhood_group'], palette="plasma")
fig = plt.gcf()
fig.set_size_inches(15,5)
plt.title('Neighbourhood Group')
# Out:
# Text(0.5, 1.0, 'Neighbourhood Group')

# %% [markdown]
# Most number of listings are in Manhattan followed by Brooklyn.
#
# Staten Island has least number of properties.

# %%
#neighbourhood_group on map
plt.figure(figsize=(15,5))
sns.scatterplot(airbnb.longitude,airbnb.latitude,hue=airbnb.neighbourhood_group,palette="plasma")
plt.title('Neighbourhood Group')
# Out:
# Text(0.5, 1.0, 'Neighbourhood Group')

# %% [markdown]
# ### 3.neighbourhood

# %%
#Let's find the number of unique neighbourhoods
airbnb.neighbourhood.nunique()
# Out:
# 221

# %% [markdown]
# There are 221 different Neighbourhoods in 5 Neighbourhood Groups

# %%
#Let's find the name of unique neighbourhoods
airbnb.neighbourhood.unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#        'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village',
#        'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Brooklyn Heights',
#        'Carroll Gardens', 'Gowanus', 'Flatlands', 'Cobble Hill',
#        'Flushing', 'Boerum Hill', 'Sunnyside', 'DUMBO', 'St. George',
#        'Highbridge', 'Financial District', 'Ridgewood',
#        'Morningside Heights', 'Jamaica', 'Middle Village', 'NoHo',
#        'Ditmars Steinway', 'Flatiron District', 'Roosevelt Island',
# ...

# %%
Top_10_Neighbourhoods_With_Most_Pproperties =airbnb.neighbourhood.value_counts().head(10)
Top_10_Neighbourhoods_With_Most_Pproperties
# Out:
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1564
# Midtown               1545
# Name: neighbourhood, dtype: int64

# %%
plt.figure(figsize=(15, 5))
x = list(Top_10_Neighbourhoods_With_Most_Pproperties.index)
y = list(Top_10_Neighbourhoods_With_Most_Pproperties.values)
plt.barh(x, y)
plt.title("Most Popular Neighbourhoods")
plt.xlabel("Number of host who have properties in this area")
# Out:
# Text(0.5, 0, 'Number of host who have properties in this area')

# %% [markdown]
# ### 4.room_type

# %%
#Let's find the number of unique room_type
airbnb.room_type.nunique()
# Out:
# 3

# %%
#Names of unique room_type
airbnb.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
sns.countplot(airbnb['room_type'], palette="plasma")
fig = plt.gcf()
fig.set_size_inches(15,5)
plt.title('Room Type')
# Out:
# Text(0.5, 1.0, 'Room Type')

# %%
#room_type on map
plt.figure(figsize=(15,5))
sns.scatterplot(airbnb.longitude,airbnb.latitude,hue=airbnb.room_type , palette="coolwarm")
plt.title('Room Type')
# Out:
# Text(0.5, 1.0, 'Room Type')

# %% [markdown]
# ### 5.price

# %%
plt.figure(figsize=(15,5))
sns.distplot(airbnb['price'],hist=True, kde=False, bins = 1000, color = 'blue')
plt.xlim(0, 1000)
plt.title('Price Distribution')
# Out:
# Text(0.5, 1.0, 'Price Distribution')

# %%
airbnb.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# ### 6.minimum_nights

# %%
plt.figure(figsize=(15,5))
sns.distplot(airbnb['minimum_nights'],hist=True, kde=False, bins = 500, color = 'blue')
plt.xlim(0, 100)
plt.title('Minimum Nights Distribution')
# Out:
# Text(0.5, 1.0, 'Minimum Nights Distribution')

# %%
airbnb.minimum_nights.describe()
# Out:
# count    48895.000000
# mean         7.029962
# std         20.510550
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %% [markdown]
# ### 7.number_of_reviews

# %%
plt.figure(figsize=(15,5))
sns.distplot(airbnb['number_of_reviews'],hist=True, kde=False, bins = 500, color = 'blue')
plt.xlim(0, 100)
plt.title('Number of Reviews Distribution')
# Out:
# Text(0.5, 1.0, 'Number of Reviews Distribution')

# %%
airbnb.number_of_reviews.describe()
# Out:
# count    48895.000000
# mean        23.274466
# std         44.550582
# min          0.000000
# 25%          1.000000
# 50%          5.000000
# 75%         24.000000
# max        629.000000
# Name: number_of_reviews, dtype: float64

# %% [markdown]
# ### 8.reviews_per_month

# %%
plt.figure(figsize=(15,5))
sns.distplot(airbnb['reviews_per_month'],hist=True, kde=False, bins = 100, color = 'blue')
plt.xlim(0, 10)
plt.title('Reviews Per Month Distribution')
# Out:
# Text(0.5, 1.0, 'Reviews Per Month Distribution')

# %%
airbnb.reviews_per_month.describe()
# Out:
# count    48895.000000
# mean         1.090910
# std          1.597283
# min          0.000000
# 25%          0.040000
# 50%          0.370000
# 75%          1.580000
# max         58.500000
# Name: reviews_per_month, dtype: float64

# %% [markdown]
# ### 9.availability_365

# %%
plt.figure(figsize=(15,5))
sns.distplot(airbnb[airbnb['availability_365'] > 0]['availability_365'],hist=True, kde=False, bins = 365, color = 'blue')
plt.xlim(0, 365)
plt.title('availability_365 Distribution')
# Out:
# Text(0.5, 1.0, 'availability_365 Distribution')

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(airbnb.longitude,airbnb.latitude,hue=airbnb.availability_365)
plt.title('availability_365 Distribution')
# Out:
# Text(0.5, 1.0, 'availability_365 Distribution')

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ### 1.room_type and neighbourhood_group

# %%
sns.countplot(airbnb['neighbourhood_group'],  hue =airbnb['room_type'] , palette="plasma")
fig = plt.gcf()
fig.set_size_inches(15,6)
plt.title('Distribution of Room Types in different Neighbourhood Groups')
# Out:
# Text(0.5, 1.0, 'Distribution of Room Types in different Neighbourhood Groups')

# %% [markdown]
# We can see there are no shared rooms available in Staten Island and Bronx

# %% [markdown]
# ### 2.price and neighbourhood_group

# %%
#Creating a new DataFrame to describe prices for different neighbourhood groups
Price_DF = airbnb[['neighbourhood_group', 'price']]
Price_DF.head()
# Out:
#   neighbourhood_group  price
# 0            Brooklyn    149
# 1           Manhattan    225
# 2           Manhattan    150
# 3            Brooklyn     89
# 4           Manhattan     80

# %%
Price_DF.groupby('neighbourhood_group')['price'].describe()
# Out:
#                        count        mean         std   min   25%    50%  \
# neighbourhood_group
# Bronx                 1091.0   87.496792  106.709349   0.0  45.0   65.0
# Brooklyn             20104.0  124.383207  186.873538   0.0  60.0   90.0
# Manhattan            21661.0  196.875814  291.383183   0.0  95.0  150.0
# Queens                5666.0   99.517649  167.102155  10.0  50.0   75.0
# Staten Island          373.0  114.812332  277.620403  13.0  50.0   75.0
#
#                        75%      max
# neighbourhood_group
# Bronx                 99.0   2500.0
# Brooklyn             150.0  10000.0
# Manhattan            220.0  10000.0
# Queens               110.0  10000.0
# Staten Island        110.0   5000.0

# %% [markdown]
# Average price of properties in Manhattan is highest and Average price of properties in Bronx is lowest

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=Price_DF, x='neighbourhood_group', y='price' , palette="plasma")
plt.title('Distribution of Prices in different Neighbourhood Groups')
# Out:
# Text(0.5, 1.0, 'Distribution of Prices in different Neighbourhood Groups')

# %% [markdown]
# From the boxplot we can see that there are a lot of outliers for price

# %%
#Removing skewed prices
plt.figure(figsize=(15,5))
sns.boxplot(data=Price_DF[Price_DF['price'] <= 500], x='neighbourhood_group', y='price', palette="plasma")
plt.title('Distribution of Prices in different Neighbourhood Groups')
# Out:
# Text(0.5, 1.0, 'Distribution of Prices in different Neighbourhood Groups')

# %%
#Removing skewed prices
plt.figure(figsize=(15,5))
sns.violinplot(data=Price_DF[Price_DF['price'] <= 500], x='neighbourhood_group', y='price', palette="plasma")
plt.title('Distribution of Prices in different Neighbourhood Groups')
# Out:
# Text(0.5, 1.0, 'Distribution of Prices in different Neighbourhood Groups')

# %% [markdown]
# # Univariate and Bivariate Analysis

# %% [markdown]
# # Correlation Matrix

# %%
#Plot the Correlation matrix
corr = airbnb.corr(method='kendall')
plt.figure(figsize=(20,10))
sns.heatmap(corr, annot=True)

# %% [markdown]
# # 5.price

# %%
#Creating a new DataFrame to describe prices for different neighbourhood groups
Price_DF = airbnb[['neighbourhood_group', 'price']]
Price_DF.head()
# Out:
#   neighbourhood_group  price
# 0            Brooklyn    149
# 1           Manhattan    225
# 2           Manhattan    150
# 3            Brooklyn     89
# 4           Manhattan     80

# %%
Price_DF.groupby('neighbourhood_group')['price'].describe()
# Out:
#                        count        mean         std   min   25%    50%  \
# neighbourhood_group
# Bronx                 1091.0   87.496792  106.709349   0.0  45.0   65.0
# Brooklyn             20104.0  124.383207  186.873538   0.0  60.0   90.0
# Manhattan            21661.0  196.875814  291.383183   0.0  95.0  150.0
# Queens                5666.0   99.517649  167.102155  10.0  50.0   75.0
# Staten Island          373.0  114.812332  277.620403  13.0  50.0   75.0
#
#                        75%      max
# neighbourhood_group
# Bronx                 99.0   2500.0
# Brooklyn             150.0  10000.0
# Manhattan            220.0  10000.0
# Queens               110.0  10000.0
# Staten Island        110.0   5000.0

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=Price_DF, x='neighbourhood_group', y='price' , palette="plasma")
plt.title('Distribution of Prices in different Neighbourhood Groups')
# Out:
# Text(0.5, 1.0, 'Distribution of Prices in different Neighbourhood Groups')

# %%
#From the boxplot we can see that there are a lot of outliers for price

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=Price_DF[Price_DF['price'] <= 500], x='neighbourhood_group', y='price', palette="plasma")
plt.title('Distribution of Prices in different Neighbourhood Groups')
# Out:
# Text(0.5, 1.0, 'Distribution of Prices in different Neighbourhood Groups')

# %%
plt.figure(figsize=(15,5))
sns.violinplot(data=Price_DF[Price_DF['price'] <= 500], x='neighbourhood_group', y='price', palette="plasma")
plt.title('Distribution of Prices in different Neighbourhood Groups')
# Out:
# Text(0.5, 1.0, 'Distribution of Prices in different Neighbourhood Groups')

# %%
plt.figure(figsize=(15,5))
sns.violinplot(data=airbnb[airbnb['price'] <= 500], x='room_type', y='price', palette="plasma")
plt.title('Distribution of Prices for different Room Types')
# Out:
# Text(0.5, 1.0, 'Distribution of Prices for different Room Types')
